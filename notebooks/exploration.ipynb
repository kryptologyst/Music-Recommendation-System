# %% [markdown]
# # Music Recommendation System - Exploration
#
# This notebook demonstrates how to use the music recommendation system for data exploration, model training, and evaluation.

# %%
import sys
import os
sys.path.append('.')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data import MusicDataLoader
from src.models import ContentBasedRecommender, CollaborativeFilteringRecommender, HybridRecommender
from src.evaluation import RecommenderEvaluator
from src.utils import set_seed

# Set random seed for reproducibility
set_seed(42)

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
